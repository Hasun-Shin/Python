# %% [markdown]
# ## print 문

# %%
print('Life',1)
# Out:
# Life 1

# %%
print('Life', end=' ')
print('is', end=' ')
print('too', end=' ')
print('short', end=' ')
# Out:
# Life is too short

# %% [markdown]
# ## 파일
# ![image.png](attachment:image.png)

# %%
open('파일명', '모드')

# r 읽기 모드 
file = open('d:/test.txt', 'r')
print(file.read())
file.close()

# w 쓰기 모드

file = open('d:/test.txt', 'w')
file.write('hello')
file.close()


# x 쓰기 모드 . 반드시 새로운 파일을 만들 때만 적용됨 .
file = open('d:/test.txt', 'x')
file.write('hello')
file.close()
# -> 파일이 이미 존재한다고 오류가 난다.

#추가 모드 (a)
# 대상 파일 끝 부분에 추가 .

# %%
f = open('c:/dev/text.txt','rt',encoding='utf-8')
f.read()
f.close()
# Out:
# '12AB가나★○'

# %% [markdown]
# ### 파일의 내용을 읽은 후 숫자들의 합 구하기

# %%
f = open('c:/dev/numbers.txt','rt',encoding='utf-8')
a = f.read().split()

total = 0
for i in a :
    b = int(i)
    
    total = total + b
print(total)
# Out:
# 141

# %% [markdown]
# ### 파일의 내용을 읽은 후 알파벳 t 가 포함된 단어만 출력

# %%
f = open('c:/dev/test_data.txt','rt',encoding='utf-8')
a = f.read().split()
#print(a)
for i in a :
    if 't' in i :
        print(i)
# Out:
# python
# kotlin
# fortran
