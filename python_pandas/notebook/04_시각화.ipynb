# %% [markdown]
# # 4장.데이터시각화
# ## 앤스콤 데이터 집합 불러온 후 그래프 그리기(77쪽)

# %% [markdown]
# ### 1. 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns 
anscombe = sns.load_dataset("anscombe") 
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
import pandas as pd

# print(anscombe.groupby('dataset')['x','y'].mean())
# print(anscombe.groupby('dataset')['x','y'].std())
# print(anscombe.groupby('dataset')['x','y'].min())
# print(anscombe.groupby('dataset')['x','y'].quantile(q=0.25))
# print(anscombe.groupby('dataset')['x','y'].quantile(q=0.50))
# print(anscombe.groupby('dataset')['x','y'].quantile(q=0.75))
# print(anscombe.groupby('dataset')['x','y'].max())


count=anscombe.groupby('dataset')['x','y'].count()
mean=anscombe.groupby('dataset')['x','y'].mean()
std=anscombe.groupby('dataset')['x','y'].std()
mins=anscombe.groupby('dataset')['x','y'].min()
q25=anscombe.groupby('dataset')['x','y'].quantile(q=0.25)
q50=anscombe.groupby('dataset')['x','y'].quantile(q=0.50)
q75=anscombe.groupby('dataset')['x','y'].quantile(q=0.75)
maxes=anscombe.groupby('dataset')['x','y'].max()

# pd.concat([count,mean],axis=1)

# count=anscombe[['x','y']].count()
# mean=anscombe[['x','y']].mean()
# std=anscombe[['x','y']].std()
# mins=anscombe[['x','y']].min()
# q25=anscombe[['x','y']].quantile(q=0.25)
# q50=anscombe[['x','y']].quantile(q=0.50)
# q75=anscombe[['x','y']].quantile(q=0.75)
# maxes=anscombe[['x','y']].max()

pd.concat([count,mean,std,mins,q25,q50,q75,maxes],axis=1)


x1countlist = count['x'].values.tolist()
# Out:
# C:\Users\student\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   if sys.path[0] == '':
# C:\Users\student\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   del sys.path[0]
# C:\Users\student\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\student\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   from ipykernel import kernelapp as app
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II'] 
dataset_3 = anscombe[anscombe['dataset'] == 'III'] 
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o') 
axes2.plot(dataset_2['x'], dataset_2['y'], 'r*') 
axes3.plot(dataset_3['x'], dataset_3['y'], 'b+') 
axes4.plot(dataset_4['x'], dataset_4['y'], 'k.')

fig

# %%
axes1.set_title("dataset_1") 
axes2.set_title("dataset_2")
axes3.set_title("dataset_3") 
axes4.set_title("dataset_4")

fig

# %%
fig.suptitle("Anscombe Data")

fig

# %%
fig.tight_layout() #겹쳐지지 않게 


fig

# %%
d1=dataset_1.describe()
d1.reset_index().rename({'x':'x1'},axis=1)
d1.reset_index().rename({'y':'y1'},axis=1)
d2=dataset_2.describe()
d3=dataset_3.describe()
d4=dataset_4.describe()




pd.concat([d1,d2,d3,d4],axis=1)
# Out:
#                x          y          x          y          x          y  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# 문자열을 파이썬 객체로 변경하기 위해서는 eval 함수를 쓴다

# %%
import numpy as np
np.unique(anscombe.dataset)
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
anscomes = []

for i in range(1,5):
    tmp = eval('dataset_'+str(i)).describe()
    tmp.columns = [col + str(i) for col in tmp.columns]
    anscomes.append(tmp)

# %%
pd.concat(anscomes, axis=1)
# Out:
#               x1         y1         x2         y2         x3         y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               x4         y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %% [markdown]
# # 직접 해보세요!
# ## 기초 그래프 그리기 ― 히스토그램, 산점도, 박스 그래프(84쪽)

# %%
tips = sns.load_dataset("tips") 
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
fig = plt.figure() 
axes1 = fig.add_subplot(1, 1, 1)

# %%
axes1.hist(tips['total_bill'], bins=10) 
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('total_bill') 
axes1.set_ylabel('frequency') 

fig

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(tips['total_bill'], tips['tip']) 
axes1.set_title('Scatterplot of Total Bill vs Tip') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip'], 
     tips[tips['sex'] == 'Male']['tip']], 
    labels=['Female', 'Male'])


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
female = tips[tips['sex']=='Female']
femalesumbill = female.total_bill.sum()
femalesumtip = female.tip.sum()
femaleratio = femalesumtip/femalesumbill
femaleratio


male = tips[tips['sex']=='Male']
malesumbill = male.total_bill.sum()
malesumtip = male.tip.sum()
maleratio = malesumtip/femalesumbill
maleratio


boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1, 1, 1) 

axes1.boxplot( 
    [tips[tips['sex'] == 'Female']['tip']/tips[tips['sex'] == 'Female']['total_bill'], 
     tips[tips['sex'] == 'Male']['tip']/tips[tips['sex'] == 'Male']['total_bill'] ],
    labels=['Female', 'Male']) 


axes1.set_xlabel('Sex') 
axes1.set_ylabel('Tip') 
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
li = [.1, 100, 50]
import math

# %%
li2 = []
for i in li:
    li2.append(math,log10(i))
    
li2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-6bead14ef836> in <module>
#       1 li2 = []
#       2 for i in li:
# ----> 3     li2.append(math,log10(i))
#       4
#       5 li2
#
# NameError: name 'log10' is not defined

# %%
list(map(math,log10,li))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-218053a98b07> in <module>
# ----> 1 list(map(math,log10,li))
#
# NameError: name 'log10' is not defined

# %%
def recode_sex(sex):
    if sex =='Female':
        return 0
    else:
        return 1

# %% [markdown]
# # 직접 해보세요!
# ## 다변량 데이터로 다변량 그래프 그리기 ─ 산점도 그래프(89쪽)

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0 
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1, 1, 1) 
axes1.scatter(
    x=tips['total_bill'], 
    y=tips['tip'],    
    s=tips['size'] * 10,    
    c=tips['sex_color'],
    alpha=0.5)

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size') 
axes1.set_xlabel('Total Bill') 
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# # 직접 해보세요!
# ## 단변량 그래프 그리기 ― 히스토그램(91쪽)

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill']) 
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], kde=False) 
ax.set_title('Total Bill Histogram') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist=False) 
ax.set_title('Total Bill Density') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Unit Probability')
# Out:
# Text(0, 0.5, 'Unit Probability')

# %%
hist_den_rug, ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], rug=True) 
ax.set_title('Total Bill Histogram with Density and Rug Plot') 
ax.set_xlabel('Total Bill')
# Out:
# C:\Users\phk70\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,0,'Total Bill')

# %%
ax = plt.subplots() 
ax = sns.countplot('day', data=tips) 
ax.set_title('Count of days') 
ax.set_xlabel('Day of the Week') 
ax.set_ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# # 직접 해보세요!
# ## 다양한 종류의 이변량 그래프 그리기(95쪽)

# %% [markdown]
# ### 1. seaborn 라이브러리로 산점도 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips) 
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# C:\Users\phk70\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\phk70\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1.03,'Joint Plot of Total Bill and Tip')

# %%
hexbin = sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex") 
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# C:\Users\phk70\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\phk70\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1.03,'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# ### 4. 이차원 밀집도 그리기

# %%
kde, ax = plt.subplots() 
ax = sns.kdeplot(data=tips['total_bill'],
                 data2=tips['tip'], 
                 shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0,0.5,'Tip')

# %% [markdown]
# ### 5. 바 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.barplot(x='time', y='total_bill', data=tips) 
ax.set_title('Bar plot of average total bill for time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Average total bill')
# Out:
# Text(0,0.5,'Average total bill')

# %% [markdown]
# ### 6. 박스 그래프 그리기

# %%
ax = plt.subplots() 
ax = sns.boxplot(x='time', y='total_bill', data=tips) 
ax.set_title('Boxplot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0,0.5,'Total Bill')

# %%
ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', data=tips) 
ax.set_title('Violin plot of total bill by time of day') 
ax.set_xlabel('Time of day') 
ax.set_ylabel('Total Bill')
# Out:
# Text(0,0.5,'Total Bill')

# %% [markdown]
# ### 8. 관계 그래프 그리기

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips) 
pair_grid = pair_grid.map_upper(sns.regplot) 
pair_grid = pair_grid.map_lower(sns.kdeplot) 
pair_grid = pair_grid.map_diag(sns.distplot, rug=True) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3f90ad69d1c5> in <module>
#       3 pair_grid = pair_grid.map_lower(sns.kdeplot)
#       4 pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
# ----> 5 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # 직접 해보세요!
# ## 다변량 그래프 그리기(103쪽)

# %% [markdown]
# ### 1. seaborn 라이브러리로 바이올린 그래프 그리기 ― 색상 추가

# %%
violin, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True) 
plt.show()

# %% [markdown]
# ### 2. 산점도, 관계 그래프 그리기 ― 색상 추가

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-af88a7112e25> in <module>
#       1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# ### 3. 산점도 그래프의 크기와 모양 조절하기

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10}) 
plt.show()

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o', 'x'], scatter_kws={'s': tips['size']*10}) 
plt.show()

# %% [markdown]
# ### 5. lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False)

# %%
#tips 데이터를 이용하여 tip과 total_bill로 산점도를 그리되, sex와 smoker 별로 2x2 lmplot 을 그려본다. 


tips_plot = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, row = 'sex', col='smoker')

# %% [markdown]
# lm = linear model 이다.
#  lm 은 facetgrid
#  lmplot 은 regplot(회귀) + facetgrid 이다.
#
#  여러 측면에서 본 여러 그림들 => facetgrid
#
#  regplot 에서는 격자를 못 만든다. lmplot은 격자를 만들 수 있다.

# %%
tips.head()


# Basic Scatter Plot

plt.plot('tip',  # x

         'total_bill',  # y

         data=tips, 

         linestyle='none', 

         marker='o', 

         markersize=10,

         color='blue', 

         alpha=0.5)

plt.title('Scatter Plot of iris by matplotlib', fontsize=20)

plt.xlabel('tip', fontsize=14)

plt.ylabel('total_bill', fontsize=14)

plt.show()

# %%
anscombe_plot2 = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)

# %% [markdown]
# # 알아두면 좋아요!
# ## FacetGrid 클래스로도 그룹별 그래프를 그릴 수 있습니다(108쪽)

# %%
facet = sns.FacetGrid(tips, col='time') #time 이 몇개 항목이 있는지에 따라 그 개수의 도화지를 만든다. 
facet.map(sns.distplot, 'total_bill', rug=True) # 각각의 도화지에 map 을 적용해준다. 각각 도화지에 distplot을 적용해라. 

#distplot(tips['total_bill'], rug = True)
# Out:
# C:\Users\fermat39\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\fermat39\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
facet 은 도화지 2개를 만든다. 만약에 blackfast가 있었으면 열이 3개 만들어졌을 수도...

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex',col_wrap=2) #hue='sex' 성별로 다르게 색깔을 칠하겠다. 
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet.add_legend()
facet_to_lm = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, col='day',col_wrap=2, hue='sex', size=3, scatter_kws=("s":100))
facet_to_lm = facet_to_lm.add_legend() 


###? 왜 ?? scatter _kws가 안되는 것이지. 점의 크기. 지정하는건데....
# Out:
#   File "<ipython-input-42-f3d2993fde0e>", line 4
#     facet_to_lm = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, col='day',col_wrap=2, hue='sex', size=3, scatter_kws=("s":100))
#                                                                                                                                          ^
# SyntaxError: invalid syntax

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex') 
facet.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# # 직접 해보세요!
# ## 데이터프레임과 시리즈로 그래프 그리기(110쪽)
#
# panda의 plot 메소드로 바로 그래프를 그릴 수 있다.

# %%
fig, ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
#두 개의 변수에 대해 한번에 히스토그램을 그릴 수 있다.

fig, ax = plt.subplots() 
ax = tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
fig, ax = plt.subplots() 
ax = tips['tip'].plot.kde()

# %%
fig,axes = plt.subplots(1,2)
tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=axes[0])
tips['tip'].plot.kde(ax=axes[1])

# %%
fig, ax = plt.subplots() 
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
smoker = tips.groupby(['smoker'])

# %%
import numpy as np


fig, axes = plt.subplots(2,2, sharex =True, sharey = True, figsize = (10,10))
plt.subplots_adjust(wspace=0.1, hspace = 0.1)

# adding 'color' column
tips['color'] = np.where(tips.sex == 'Female', 'red', np.where(tips.sex =='Male', 'blue' ))





            


axes[0,0] = tips[(tips['smoker']=='Yes')&(tips['time']=='Lunch')].plot.scatter(x='total_bill', y='tip', ax=axes[0,0]) 
axes[0,1] = tips[(tips['smoker']=='Yes')&(tips['time']=='Dinner')].plot.scatter(x='total_bill', y='tip', ax=axes[0,1]) 
axes[1,0] = tips[(tips['smoker']=='No')&(tips['time']=='Lunch')].plot.scatter(x='total_bill', y='tip', ax=axes[1,0]) 
axes[1,1] = tips[(tips['smoker']=='No')&(tips['time']=='Dinner')].plot.scatter(x='total_bill', y='tip', ax=axes[1,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-a9b08e955242> in <module>
#       6
#       7 # adding 'color' column
# ----> 8 tips['color'] = np.where(tips.sex == 'Female', 'red', np.where(tips.sex =='Male', 'blue' ))
#       9
#      10
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given

# %%
current_palette=sns.color_palette()
sns.palplot(current_palette)

# %%
current_palette[:2]
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725)]

# %%
# cur_colors = {}
# sexes = ['Male', 'Female']
# for i in range(2):
#     col = []
#     for j in range(3):
#         tmpstr=hex(round(current_palette[i][j]*256))[:2]
#         tmpstr= '0' + tmpstr if len(tmptr)<2 else 
#         col.append(tmpstr)
#     cur_colors[sexes[i]] = '#' + ''.join

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-41d7ef954216> in <module>
# ----> 1 fig, ax = plt.subplots()
#       2 ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots() 
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
fig, axes = plt.subplots(1,3) 
boxBill = tips['total_bill'].plot.box(ax=axes[0])
boxTip = tips['tip'].plot.box(ax=axes[1])
boxSize = tips['size'].plot.box(ax=axes[2])

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-17ff4c38ab50> in <module>
# ----> 1 fig, axes = plt.subplots(1,3)
#       2 boxBill = tips['total_bill'].plot.box(ax=axes[0])
#       3 boxTip = tips['tip'].plot.box(ax=axes[1])
#       4 boxSize = tips['size'].plot.box(ax=axes[2])
#       5
#
# NameError: name 'plt' is not defined

# %%
boxBill.get_xlabel
# Out:
# <bound method Axes.get_xlabel of <matplotlib.axes._subplots.AxesSubplot object at 0x0000029E7D399588>>

# %% [markdown]
# # 직접 해보세요!
# ## 그래프에 스타일 적용하기(114쪽)

# %%
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
sns.set_style('whitegrid') 
fig, ax = plt.subplots() 
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %%
fig = plt.figure() 
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks'] 
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style) 
        
fig.tight_layout()
